# %% [markdown]
# # Test for output sanitization

# %%
a = 1
b = 2
a + b

# %%
# [pin] -- do not remove output
print('日本語')
# Out:
# 日本語

# %%
import matplotlib.pyplot as plt

# %%
t = list(range(10))
s = list(range(10))
fig, ax = plt.subplots()
ax.plot(t, s)
ax.grid()
plt.show()

# %%
# [donotremove]
fig, ax = plt.subplots()
ax.plot(t, s)
ax.grid()
plt.show()
